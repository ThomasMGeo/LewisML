# %% [markdown]
# # Prediction of Porosity with SVM

# %%
# If you have installation questions, please reach out
import pandas as pd # data storage
import numpy as np  # math and stuff

import sklearn  
import datetime
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error

from sklearn.model_selection import train_test_split

from sklearn.metrics import median_absolute_error, max_error, mean_squared_error

from sklearn import svm
from sklearn.svm import SVR
from sklearn.pipeline import make_pipeline
from sklearn.model_selection import GridSearchCV
from sklearn import preprocessing
from sklearn.preprocessing import StandardScaler

# %%
import defaults
from defaults import framecleaner, splitterz

import svm_models
from svm_models import svm_por

# %% [markdown]
# # Dataframes

# %%
df0  = pd.read_csv('../../core_to_wl_merge/OS0_Merged_dataset_imputed_08_23_2021.csv')

df1 = pd.read_csv('../../core_to_wl_merge/OS1_Merged_dataset_imputed_08_23_2021.csv')

df2 = pd.read_csv('../../core_to_wl_merge/OS2_Merged_dataset_imputed_08_23_2021.csv')
# Out:
# C:\Users\tmartin\.conda\envs\lewisml\lib\site-packages\IPython\core\interactiveshell.py:3441: DtypeWarning: Columns (17) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
param_dict ={
    "jobnum": 4, #Number of Cores
    "dataset": ['CAL', 'GR', 'DT', 'SP', 'DENS', 'PE', 'RESD', 'PHIN', 'PHID', 'GR_smooth',  'PE_smooth', 'He_por'],
    "inputs": ['CAL', 'GR', 'DT', 'SP', 'DENS', 'PE', 'RESD', 'PHIN', 'PHID', 'GR_smooth',  'PE_smooth'],
    "target": ['He_por']}

# %% [markdown]
# # Offset 0

# %%
df0 = df0[df0.USGS_ID != 'E997']

#Create the dataset
X, Y_array = framecleaner(df0, param_dict['dataset'], param_dict['inputs'], param_dict['target'] )

#Split the dataset
X_train, X_test, y_train, y_test = splitterz(X.values, Y_array)

df_OS0 = svm_por(X_train, X_test, y_train, y_test, jobs=param_dict['jobnum'], OS='OS0')
df_OS0
# Out:
# C:\Users\tmartin\.conda\envs\lewisml\lib\site-packages\pandas\util\_decorators.py:311: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return func(*args, **kwargs)
# C:\Users\tmartin\.conda\envs\lewisml\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# Mean Squared Error: 2.047211
# Max Error: 8.573428
# Median Abs Error: 0.511844
# C:\Users\tmartin\.conda\envs\lewisml\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# C:\Users\tmartin\.conda\envs\lewisml\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# Mean Squared Error: 1.678710
# Max Error: 6.081812
# Median Abs Error: 0.933818
#   target Offset       MSE       MAE  ...  month  year    model  version
# 0    por    OS0  2.047211  0.511844  ...      9  2021  SVM-RBF   0.24.2
# 1    por    OS0  1.678710  0.933818  ...      9  2021  SVM-RBF   0.24.2
#
# [2 rows x 10 columns]

# %% [markdown]
# # Offset 1

# %%
df1 = df1[df1.USGS_ID != 'E997']

#Create the dataset
X1, Y1_array = framecleaner(df1, param_dict['dataset'], param_dict['inputs'], param_dict['target'] )

#Split the dataset
X1_train, X1_test, y1_train, y1_test = splitterz(X1.values, Y1_array)

df_OS1 = svm_por(X1_train, X1_test, y1_train, y1_test, jobs=param_dict['jobnum'], OS='OS1')
df_OS1
# Out:
# C:\Users\tmartin\.conda\envs\lewisml\lib\site-packages\pandas\util\_decorators.py:311: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return func(*args, **kwargs)
# C:\Users\tmartin\.conda\envs\lewisml\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# Mean Squared Error: 2.225102
# Max Error: 8.770869
# Median Abs Error: 0.543951
# C:\Users\tmartin\.conda\envs\lewisml\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# C:\Users\tmartin\.conda\envs\lewisml\lib\site-packages\sklearn\svm\_base.py:255: ConvergenceWarning: Solver terminated early (max_iter=150).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn('Solver terminated early (max_iter=%i).'
# C:\Users\tmartin\.conda\envs\lewisml\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# C:\Users\tmartin\.conda\envs\lewisml\lib\site-packages\sklearn\svm\_base.py:255: ConvergenceWarning: Solver terminated early (max_iter=150).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn('Solver terminated early (max_iter=%i).'
# Mean Squared Error: 2.777990
# Max Error: 9.069239
# Median Abs Error: 1.524101
#   target Offset       MSE       MAE  ...  month  year    model  version
# 0    por    OS1  2.225102  0.543951  ...      9  2021  SVM-RBF   0.24.2
# 1    por    OS1  2.777990  1.524101  ...      9  2021  SVM-RBF   0.24.2
#
# [2 rows x 10 columns]

# %% [markdown]
# # Offset 2

# %%
df2 = df2[df2.USGS_ID != 'E997']

#Create the dataset
X2, Y2_array = framecleaner(df2, param_dict['dataset'], param_dict['inputs'], param_dict['target'] )

#Split the dataset
X2_train, X2_test, y2_train, y2_test = splitterz(X2.values, Y2_array)

df_OS2 = svm_por(X2_train, X2_test, y2_train, y2_test, jobs=param_dict['jobnum'], OS='OS2')
df_OS2
# Out:
# C:\Users\tmartin\.conda\envs\lewisml\lib\site-packages\pandas\util\_decorators.py:311: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return func(*args, **kwargs)
# C:\Users\tmartin\.conda\envs\lewisml\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# Mean Squared Error: 1.743476
# Max Error: 8.657109
# Median Abs Error: 0.613104

# %% [markdown]
# # Combine Results

# %%
frames = [df_OS0, df_OS1, df_OS2]
results = pd.concat(frames)
results
# Out:
#   target Offset       MSE       MAE  MaxError  day  month  year    model  \
# 0    por    OS0  1.947988  0.608879  8.266298    7      9  2021  SVM-RBF
# 1    por    OS0  1.693597  0.944896  4.742143    7      9  2021  SVM-RBF
# 0    por    OS1  1.840849  0.506104  8.127026    7      9  2021  SVM-RBF
# 1    por    OS1  1.801433  0.843171  6.967485    7      9  2021  SVM-RBF
# 0    por    OS2  2.165219  0.568150  8.598815    7      9  2021  SVM-RBF
# 1    por    OS2  1.944131  0.896365  9.462616    7      9  2021  SVM-RBF
#
#   version
# 0  0.24.2
# 1  0.24.2
# 0  0.24.2
# 1  0.24.2
# 0  0.24.2
# 1  0.24.2
