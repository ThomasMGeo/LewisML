# %% [markdown]
# # Predicting Porosity using Catboost

# %%
# If you have installation questions, please reach out
import seaborn as sns
import pandas as pd # data storage
import catboost as cats # graident boosting 

from catboost import CatBoostRegressor, Pool

import numpy as np  # math and stuff
import matplotlib.pyplot as plt # plotting utility
import sklearn # ML and stats

print('catboost ver:', cats.__version__)
print('scikit ver:', sklearn.__version__)

import datetime

from sklearn.preprocessing import MinMaxScaler, RobustScaler
from sklearn.model_selection import cross_val_score, KFold, train_test_split
from sklearn.utils.class_weight import compute_sample_weight
from sklearn.metrics import max_error, mean_squared_error, median_absolute_error
# Out:
# catboost ver: 0.26.1
# scikit ver: 1.0.1

# %%
from catboostmodels import catboost_he_por
from defaults import framecleaner, splitterz

# %% [markdown]
# # Data

# %%
df0  = pd.read_csv('../../core_to_wl_merge/OS0_Merged_dataset_imputed_08_23_2021.csv')

df1 = pd.read_csv('../../core_to_wl_merge/OS1_Merged_dataset_imputed_08_23_2021.csv')

df2 = pd.read_csv('../../core_to_wl_merge/OS2_Merged_dataset_imputed_08_23_2021.csv')
# Out:
# C:\Users\tmartin\.conda\envs\lewisml\lib\site-packages\IPython\core\interactiveshell.py:3441: DtypeWarning: Columns (17) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %% [markdown]
# # Parameters

# %%
param_dict ={
    "iter" : 200,       #Maximum iterations
    "GPUorCPU": "CPU", #CPU is fine for this dataset on most laptops
    "dataset": ['CAL', 'GR', 'DT', 'SP', 'DENS', 'PE', 'RESD', 'PHID', 'He_por'],
    "inputs":  ['CAL', 'GR', 'DT', 'SP', 'DENS', 'PE', 'RESD', 'PHID'],
    "target":  ['He_por']}

# %% [markdown]
# # Offset 0

# %%
df0 = df0[df0.USGS_ID != 'E997']

# %%
#Create the dataset
X, Y_array = framecleaner(df0, param_dict['dataset'], param_dict['inputs'], param_dict['target'] )

#Split the dataset
X_train, X_test, y_train, y_test = splitterz(X.values, Y_array)

# Run the ML workflow
df_OS0 = catboost_he_por(X_train, X_test, y_train, y_test, OS='OS0', max_iter = param_dict['iter'], CPUorGPU=param_dict['GPUorCPU'])
# Out:
# C:\Users\tmartin\.conda\envs\lewisml\lib\site-packages\pandas\util\_decorators.py:311: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return func(*args, **kwargs)
# Learning rate set to 0.104842
# 0:	learn: 1.9214047	total: 1.85ms	remaining: 368ms
# 199:	learn: 0.4999694	total: 273ms	remaining: 0us
# Root Mean Squared Error: 1.329398
# Max Error: 4.725568
# Median Abs Error: 0.660926
#
# bestTest = 1.767773519
# bestIteration = 199
#
#
# bestTest = 1.720074768
# bestIteration = 180
#
#
# bestTest = 1.741816905
# bestIteration = 120
#
#
# bestTest = 1.710641253
# bestIteration = 52
#
#
# bestTest = 1.757904431
# bestIteration = 199
#
#
# bestTest = 1.725947804
# bestIteration = 180
#
#
# bestTest = 1.719760579
# bestIteration = 95
#
#
# bestTest = 1.735483994
# bestIteration = 30
#
#
# bestTest = 1.775358311
# bestIteration = 192
#
#
# bestTest = 1.752823609
# bestIteration = 199
#
#
# bestTest = 1.765178517
# bestIteration = 73
#
#
# bestTest = 1.664378769
# bestIteration = 90
#
#
# bestTest = 1.790449942
# bestIteration = 199
#
#
# bestTest = 1.758912186
# bestIteration = 173
#
#
# bestTest = 1.756385034
# bestIteration = 102
#
#
# bestTest = 1.691157209
# bestIteration = 33
#
#
# bestTest = 1.790295117
# bestIteration = 188
#
#
# bestTest = 1.759222669
# bestIteration = 198
#
#
# bestTest = 1.745596984
# bestIteration = 175
#
#
# bestTest = 1.706489757
# bestIteration = 65
#
#
# bestTest = 1.802311012
# bestIteration = 189
#
#
# bestTest = 1.79285171
# bestIteration = 196
#
#
# bestTest = 1.753046683
# bestIteration = 185
#
#
# bestTest = 1.795151895
# bestIteration = 15
#
#
# bestTest = 1.669411221
# bestIteration = 199
#
#
# bestTest = 1.657030609
# bestIteration = 195
#
#
# bestTest = 1.685047709
# bestIteration = 83
#
#
# bestTest = 1.584157887
# bestIteration = 140
#
#
# bestTest = 1.654574042
# bestIteration = 175
#
#
# bestTest = 1.68432156
# bestIteration = 62
#
#
# bestTest = 1.610457237
# bestIteration = 175
#
#
# bestTest = 1.580083636
# bestIteration = 60
#
#
# bestTest = 1.682834377
# bestIteration = 174
#
#
# bestTest = 1.676233047
# bestIteration = 199
#
#
# bestTest = 1.615462007
# bestIteration = 198
#
#
# bestTest = 1.611455821
# bestIteration = 81
#
#
# bestTest = 1.705690034
# bestIteration = 183
#
#
# bestTest = 1.618359319
# bestIteration = 180
#
#
# bestTest = 1.637027728
# bestIteration = 27
#
#
# bestTest = 1.620793228
# bestIteration = 91
#
#
# bestTest = 1.6691286
# bestIteration = 199
#
#
# bestTest = 1.692087508
# bestIteration = 104
#
#
# bestTest = 1.616819367
# bestIteration = 167
#
#
# bestTest = 1.656909092
# bestIteration = 76
#
#
# bestTest = 1.665987687
# bestIteration = 132
#
#
# bestTest = 1.675136475
# bestIteration = 95
#
#
# bestTest = 1.66007916
# bestIteration = 41
#
#
# bestTest = 1.63971941
# bestIteration = 62
#
#
# bestTest = 1.643374008
# bestIteration = 97
#
#
# bestTest = 1.608263932
# bestIteration = 34
#
#
# bestTest = 1.628763395
# bestIteration = 166
#
#
# bestTest = 1.779657178
# bestIteration = 21
#
#
# bestTest = 1.623979484
# bestIteration = 110
#
#
# bestTest = 1.652814962
# bestIteration = 33
#
#
# bestTest = 1.641021404
# bestIteration = 33
#
#
# bestTest = 1.719470964
# bestIteration = 17
#
#
# bestTest = 1.627883528
# bestIteration = 111
#
#
# bestTest = 1.631163535
# bestIteration = 51
#
#
# bestTest = 1.630280506
# bestIteration = 46
#
#
# bestTest = 1.677058229
# bestIteration = 165
#
#
# bestTest = 1.657942278
# bestIteration = 91
#
#
# bestTest = 1.56608135
# bestIteration = 56
#
#
# bestTest = 1.631911465
# bestIteration = 28
#
#
# bestTest = 1.705994105
# bestIteration = 15
#
#
# bestTest = 1.656664227
# bestIteration = 137
#
#
# bestTest = 1.616141706
# bestIteration = 60
#
#
# bestTest = 1.650901614
# bestIteration = 21
#
#
# bestTest = 1.649659256
# bestIteration = 102
#
#
# bestTest = 1.667717443
# bestIteration = 101
#
#
# bestTest = 1.667335135
# bestIteration = 42
#
#
# bestTest = 1.61596439
# bestIteration = 22
#
#
# bestTest = 1.665783459
# bestIteration = 17
#
#
# bestTest = 1.767623677
# bestIteration = 83
#
#
# bestTest = 1.774061017
# bestIteration = 38
#
#
# bestTest = 1.771952091
# bestIteration = 25
#
#
# bestTest = 1.839969258
# bestIteration = 13
#
#
# bestTest = 1.712726452
# bestIteration = 96
#
#
# bestTest = 1.72034098
# bestIteration = 46
#
#
# bestTest = 1.777551949
# bestIteration = 21
#
#
# bestTest = 1.833095832
# bestIteration = 11
#
#
# bestTest = 1.751220432
# bestIteration = 108
#
#
# bestTest = 1.678960614
# bestIteration = 147
#
#
# bestTest = 1.744530287
# bestIteration = 26
#
#
# bestTest = 1.74334306
# bestIteration = 15
#
#
# bestTest = 1.700581069
# bestIteration = 123
#
#
# bestTest = 1.711430587
# bestIteration = 196
#
#
# bestTest = 1.734263941
# bestIteration = 27
#
#
# bestTest = 1.74313884
# bestIteration = 16
#
#
# bestTest = 1.698622239
# bestIteration = 128
#
#
# bestTest = 1.681267969
# bestIteration = 58
#
#
# bestTest = 1.642801987
# bestIteration = 164
#
#
# bestTest = 1.733017296
# bestIteration = 88
#
#
# bestTest = 1.720118471
# bestIteration = 129
#
#
# bestTest = 1.72435438
# bestIteration = 162
#
#
# bestTest = 1.701761516
# bestIteration = 95
#
#
# bestTest = 1.706378679
# bestIteration = 196
#
#
# bestTest = 1.720656833
# bestIteration = 107
#
#
# bestTest = 1.818217172
# bestIteration = 59
#
#
# bestTest = 1.803356747
# bestIteration = 27
#
#
# bestTest = 2.01626819
# bestIteration = 13
#
#
# bestTest = 1.739681294
# bestIteration = 128
#
#
# bestTest = 1.823135598
# bestIteration = 52
#
#
# bestTest = 1.911538407
# bestIteration = 74
#
#
# bestTest = 1.965034411
# bestIteration = 13
#
#
# bestTest = 1.717913841
# bestIteration = 148
#
#
# bestTest = 1.768989875
# bestIteration = 62
#
#
# bestTest = 1.818951575
# bestIteration = 185
#
#
# bestTest = 1.951756587
# bestIteration = 80
#
#
# bestTest = 1.681421405
# bestIteration = 143
#
#
# bestTest = 1.743032779
# bestIteration = 186
#
#
# bestTest = 1.767707811
# bestIteration = 28
#
#
# bestTest = 1.821552057
# bestIteration = 46
#
#
# bestTest = 1.717523477
# bestIteration = 146
#
#
# bestTest = 1.749456325
# bestIteration = 88
#
#
# bestTest = 1.823665621
# bestIteration = 54
#
#
# bestTest = 1.898063829
# bestIteration = 16
#
#
# bestTest = 1.70552275
# bestIteration = 193
#
#
# bestTest = 1.726984197
# bestIteration = 87
#
#
# bestTest = 1.804930162
# bestIteration = 39
#
#
# bestTest = 1.900530106
# bestIteration = 16
#
# 0:	learn: 1.9290714	total: 7.1ms	remaining: 1.41s
# 199:	learn: 0.5880334	total: 314ms	remaining: 0us
# Root Mean Squared Error: 1.322302
# Max Error: 4.512723
# Median Abs Error: 0.689935

# %%
df_OS0
# Out:
#   target offset      RMSE       MAE  MaxError  iter  day  month  year  \
# 0   poro    OS0  1.329398  0.660926  4.725568   200   11      1  2022
# 1   poro    OS0  1.322302  0.689935  4.512723   200   11      1  2022
#
#       model version
# 0  catboost  0.26.1
# 1  catboost  0.26.1

# %% [markdown]
# # Offset 1

# %%
df1 = df1[df1.He_por >= 0]

df1 = df1[df1.USGS_ID != 'E997']

# %%
#Create the dataset
X1, Y1_array = framecleaner(df1, param_dict['dataset'], param_dict['inputs'], param_dict['target'] )

#Split the dataset
X1_train, X1_test, y1_train, y1_test = splitterz(X1.values, Y1_array)

# Run the ML workflow
df_OS1 = catboost_he_por(X1_train, X1_test, y1_train, y1_test, OS='OS1', max_iter = param_dict['iter'], CPUorGPU=param_dict['GPUorCPU'])
# Out:
# Learning rate set to 0.104842
# 0:	learn: 1.9608309	total: 12.7ms	remaining: 2.52s
# C:\Users\tmartin\.conda\envs\lewisml\lib\site-packages\pandas\util\_decorators.py:311: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return func(*args, **kwargs)
# 199:	learn: 0.3834142	total: 347ms	remaining: 0us
# Root Mean Squared Error: 1.636284
# Max Error: 6.780422
# Median Abs Error: 0.620747
#
# bestTest = 1.849483134
# bestIteration = 199
#
#
# bestTest = 1.696473386
# bestIteration = 199
#
#
# bestTest = 1.610806004
# bestIteration = 174
#
#
# bestTest = 1.679381232
# bestIteration = 157
#
#
# bestTest = 1.873108974
# bestIteration = 199
#
#
# bestTest = 1.73251087
# bestIteration = 197
#
#
# bestTest = 1.722278061
# bestIteration = 199
#
#
# bestTest = 1.740524387
# bestIteration = 148
#
#
# bestTest = 1.89594378
# bestIteration = 199
#
#
# bestTest = 1.739117899
# bestIteration = 199
#
#
# bestTest = 1.71247949
# bestIteration = 195
#
#
# bestTest = 1.710646072
# bestIteration = 144
#
#
# bestTest = 1.928050064
# bestIteration = 199
#
#
# bestTest = 1.787973964
# bestIteration = 184
#
#
# bestTest = 1.791392229
# bestIteration = 199
#
#
# bestTest = 1.786664639
# bestIteration = 105
#
#
# bestTest = 1.926971486
# bestIteration = 199
#
#
# bestTest = 1.79765178
# bestIteration = 199
#
#
# bestTest = 1.731303586
# bestIteration = 199
#
#
# bestTest = 1.746854365
# bestIteration = 186
#
#
# bestTest = 1.981062139
# bestIteration = 199
#
#
# bestTest = 1.815784386
# bestIteration = 199
#
#
# bestTest = 1.766915122
# bestIteration = 198
#
#
# bestTest = 1.82885172
# bestIteration = 184
#
#
# bestTest = 1.688294295
# bestIteration = 198
#
#
# bestTest = 1.513694083
# bestIteration = 182
#
#
# bestTest = 1.635706123
# bestIteration = 199
#
#
# bestTest = 1.604999981
# bestIteration = 199
#
#
# bestTest = 1.736369858
# bestIteration = 199
#
#
# bestTest = 1.602411597
# bestIteration = 161
#
#
# bestTest = 1.599054306
# bestIteration = 149
#
#
# bestTest = 1.563668451
# bestIteration = 189
#
#
# bestTest = 1.717158295
# bestIteration = 198
#
#
# bestTest = 1.582007924
# bestIteration = 198
#
#
# bestTest = 1.656578828
# bestIteration = 197
#
#
# bestTest = 1.57023857
# bestIteration = 197
#
#
# bestTest = 1.746544376
# bestIteration = 199
#
#
# bestTest = 1.565392895
# bestIteration = 197
#
#
# bestTest = 1.613260095
# bestIteration = 199
#
#
# bestTest = 1.59832323
# bestIteration = 83
#
#
# bestTest = 1.763673591
# bestIteration = 199
#
#
# bestTest = 1.624651281
# bestIteration = 191
#
#
# bestTest = 1.538096804
# bestIteration = 164
#
#
# bestTest = 1.530878885
# bestIteration = 162
#
#
# bestTest = 1.802725733
# bestIteration = 199
#
#
# bestTest = 1.636409951
# bestIteration = 191
#
#
# bestTest = 1.615020016
# bestIteration = 188
#
#
# bestTest = 1.653063729
# bestIteration = 186
#
#
# bestTest = 1.612100161
# bestIteration = 199
#
#
# bestTest = 1.50512528
# bestIteration = 199
#
#
# bestTest = 1.580840718
# bestIteration = 155
#
#
# bestTest = 1.510556604
# bestIteration = 111
#
#
# bestTest = 1.573554823
# bestIteration = 199
#
#
# bestTest = 1.566577181
# bestIteration = 157
#
#
# bestTest = 1.510557478
# bestIteration = 198
#
#
# bestTest = 1.515061476
# bestIteration = 175
#
#
# bestTest = 1.629171494
# bestIteration = 198
#
#
# bestTest = 1.635548966
# bestIteration = 194
#
#
# bestTest = 1.511154998
# bestIteration = 197
#
#
# bestTest = 1.537727252
# bestIteration = 140
#
#
# bestTest = 1.594257717
# bestIteration = 199
#
#
# bestTest = 1.499175656
# bestIteration = 196
#
#
# bestTest = 1.539713232
# bestIteration = 194
#
#
# bestTest = 1.665303975
# bestIteration = 188
#
#
# bestTest = 1.62158058
# bestIteration = 199
#
#
# bestTest = 1.441717694
# bestIteration = 196
#
#
# bestTest = 1.482270413
# bestIteration = 157
#
#
# bestTest = 1.597880442
# bestIteration = 159
#
#
# bestTest = 1.68950511
# bestIteration = 199
#
#
# bestTest = 1.512117074
# bestIteration = 199
#
#
# bestTest = 1.52316738
# bestIteration = 198
#
#
# bestTest = 1.537342273
# bestIteration = 156
#
#
# bestTest = 1.622576479
# bestIteration = 198
#
#
# bestTest = 1.673261134
# bestIteration = 188
#
#
# bestTest = 1.660676183
# bestIteration = 152
#
#
# bestTest = 1.693101867
# bestIteration = 87
#
#
# bestTest = 1.624382877
# bestIteration = 199
#
#
# bestTest = 1.627508023
# bestIteration = 198
#
#
# bestTest = 1.687211806
# bestIteration = 193
#
#
# bestTest = 1.677426297
# bestIteration = 161
#
#
# bestTest = 1.658777562
# bestIteration = 198
#
#
# bestTest = 1.715252292
# bestIteration = 199
#
#
# bestTest = 1.670868427
# bestIteration = 197
#
#
# bestTest = 1.693813396
# bestIteration = 173
#
#
# bestTest = 1.72076166
# bestIteration = 195
#
#
# bestTest = 1.567167948
# bestIteration = 198
#
#
# bestTest = 1.785450202
# bestIteration = 199
#
#
# bestTest = 1.674470212
# bestIteration = 199
#
#
# bestTest = 1.694458004
# bestIteration = 199
#
#
# bestTest = 1.691305611
# bestIteration = 199
#
#
# bestTest = 1.582369451
# bestIteration = 184
#
#
# bestTest = 1.590461033
# bestIteration = 196
#
#
# bestTest = 1.727590585
# bestIteration = 199
#
#
# bestTest = 1.662075918
# bestIteration = 199
#
#
# bestTest = 1.710142842
# bestIteration = 193
#
#
# bestTest = 1.710431438
# bestIteration = 197
#
#
# bestTest = 1.522756901
# bestIteration = 199
#
#
# bestTest = 1.383145019
# bestIteration = 198
#
#
# bestTest = 1.511500544
# bestIteration = 64
#
#
# bestTest = 1.487671089
# bestIteration = 147
#
#
# bestTest = 1.503928972
# bestIteration = 197
#
#
# bestTest = 1.440138829
# bestIteration = 193
#
#
# bestTest = 1.561265949
# bestIteration = 199
#
#
# bestTest = 1.618693178
# bestIteration = 140
#
#
# bestTest = 1.49511907
# bestIteration = 199
#
#
# bestTest = 1.475900916
# bestIteration = 198
#
#
# bestTest = 1.614925226
# bestIteration = 199
#
#
# bestTest = 1.69891425
# bestIteration = 199
#
#
# bestTest = 1.541308198
# bestIteration = 199
#
#
# bestTest = 1.487488144
# bestIteration = 197
#
#
# bestTest = 1.432991044
# bestIteration = 182
#
#
# bestTest = 1.616993299
# bestIteration = 151
#
#
# bestTest = 1.590899789
# bestIteration = 199
#
#
# bestTest = 1.509312026
# bestIteration = 198
#
#
# bestTest = 1.510226637
# bestIteration = 198
#
#
# bestTest = 1.661983741
# bestIteration = 197
#
#
# bestTest = 1.655748562
# bestIteration = 199
#
#
# bestTest = 1.550623869
# bestIteration = 199
#
#
# bestTest = 1.559475711
# bestIteration = 199
#
#
# bestTest = 1.703787656
# bestIteration = 199
#
# 0:	learn: 1.9089439	total: 18.5ms	remaining: 3.67s
# 199:	learn: 0.0758788	total: 3.77s	remaining: 0us
# Root Mean Squared Error: 1.685559
# Max Error: 7.131229
# Median Abs Error: 0.741365

# %%
df_OS1
# Out:
#   target offset      RMSE       MAE  MaxError  iter  day  month  year  \
# 0   poro    OS1  1.636284  0.620747  6.780422   200   11      1  2022
# 1   poro    OS1  1.685559  0.741365  7.131229   200   11      1  2022
#
#       model version
# 0  catboost  0.26.1
# 1  catboost  0.26.1

# %% [markdown]
# # Offset 2

# %%
df2 = df2[df2.USGS_ID != 'E997'] # removing E997

# %%
#Create the dataset
X2, Y2_array = framecleaner(df2, param_dict['dataset'], param_dict['inputs'], param_dict['target'] )

#Split the dataset
X2_train, X2_test, y2_train, y2_test = splitterz(X2.values, Y2_array)

# Run the ML workflow
df_OS2 = catboost_he_por(X2_train, X2_test, y2_train, y2_test, OS='OS2', max_iter = param_dict['iter'], CPUorGPU=param_dict['GPUorCPU'])
# Out:
# C:\Users\tmartin\.conda\envs\lewisml\lib\site-packages\pandas\util\_decorators.py:311: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return func(*args, **kwargs)
# Learning rate set to 0.104842
# 0:	learn: 1.9117976	total: 13.4ms	remaining: 2.67s
# 199:	learn: 0.3786576	total: 301ms	remaining: 0us
# Root Mean Squared Error: 1.315132
# Max Error: 4.225198
# Median Abs Error: 0.636664
#
# bestTest = 1.686608099
# bestIteration = 148
#
#
# bestTest = 1.681513359
# bestIteration = 109
#
#
# bestTest = 1.684585983
# bestIteration = 65
#
#
# bestTest = 1.723088927
# bestIteration = 55
#
#
# bestTest = 1.619313408
# bestIteration = 165
#
#
# bestTest = 1.677255096
# bestIteration = 156
#
#
# bestTest = 1.677479829
# bestIteration = 58
#
#
# bestTest = 1.648436371
# bestIteration = 24
#
#
# bestTest = 1.655889749
# bestIteration = 177
#
#
# bestTest = 1.723906439
# bestIteration = 73
#
#
# bestTest = 1.758058037
# bestIteration = 43
#
#
# bestTest = 1.709222061
# bestIteration = 31
#
#
# bestTest = 1.634886822
# bestIteration = 198
#
#
# bestTest = 1.719333002
# bestIteration = 165
#
#
# bestTest = 1.759965299
# bestIteration = 114
#
#
# bestTest = 1.764479333
# bestIteration = 23
#
#
# bestTest = 1.642384489
# bestIteration = 199
#
#
# bestTest = 1.724970702
# bestIteration = 187
#
#
# bestTest = 1.694875148
# bestIteration = 56
#
#
# bestTest = 1.712869742
# bestIteration = 29
#
#
# bestTest = 1.656396882
# bestIteration = 199
#
#
# bestTest = 1.676623535
# bestIteration = 176
#
#
# bestTest = 1.671442506
# bestIteration = 58
#
#
# bestTest = 1.688530514
# bestIteration = 35
#
#
# bestTest = 1.757324168
# bestIteration = 105
#
#
# bestTest = 1.669001391
# bestIteration = 67
#
#
# bestTest = 1.781021717
# bestIteration = 28
#
#
# bestTest = 1.798142338
# bestIteration = 26
#
#
# bestTest = 1.726811933
# bestIteration = 158
#
#
# bestTest = 1.688291115
# bestIteration = 62
#
#
# bestTest = 1.877101069
# bestIteration = 35
#
#
# bestTest = 1.711560785
# bestIteration = 21
#
#
# bestTest = 1.726810377
# bestIteration = 153
#
#
# bestTest = 1.68551177
# bestIteration = 69
#
#
# bestTest = 1.862300553
# bestIteration = 51
#
#
# bestTest = 1.790213414
# bestIteration = 15
#
#
# bestTest = 1.73331896
# bestIteration = 146
#
#
# bestTest = 1.731115129
# bestIteration = 79
#
#
# bestTest = 1.802076003
# bestIteration = 46
#
#
# bestTest = 1.775951179
# bestIteration = 24
#
#
# bestTest = 1.709768809
# bestIteration = 197
#
#
# bestTest = 1.764811496
# bestIteration = 94
#
#
# bestTest = 1.869134117
# bestIteration = 32
#
#
# bestTest = 1.725097044
# bestIteration = 21
#
#
# bestTest = 1.756171019
# bestIteration = 172
#
#
# bestTest = 1.744103728
# bestIteration = 103
#
#
# bestTest = 1.6566157
# bestIteration = 59
#
#
# bestTest = 1.786955829
# bestIteration = 35
#
#
# bestTest = 1.659460473
# bestIteration = 199
#
#
# bestTest = 1.781987351
# bestIteration = 82
#
#
# bestTest = 1.903196062
# bestIteration = 16
#
#
# bestTest = 1.968017501
# bestIteration = 10
#
#
# bestTest = 1.675114341
# bestIteration = 129
#
#
# bestTest = 1.75392709
# bestIteration = 43
#
#
# bestTest = 1.780894249
# bestIteration = 22
#
#
# bestTest = 1.94722108
# bestIteration = 25
#
#
# bestTest = 1.679421322
# bestIteration = 117
#
#
# bestTest = 1.75008884
# bestIteration = 59
#
#
# bestTest = 1.778482915
# bestIteration = 45
#
#
# bestTest = 1.9156605
# bestIteration = 73
#
#
# bestTest = 1.68990739
# bestIteration = 198
#
#
# bestTest = 1.747846548
# bestIteration = 88
#
#
# bestTest = 1.782194496
# bestIteration = 66
#
#
# bestTest = 1.853443759
# bestIteration = 109
#
#
# bestTest = 1.71604275
# bestIteration = 199
#
#
# bestTest = 1.75043823
# bestIteration = 52
#
#
# bestTest = 1.819711841
# bestIteration = 199
#
#
# bestTest = 1.909089485
# bestIteration = 123
#
#
# bestTest = 1.685877149
# bestIteration = 199
#
#
# bestTest = 1.71983464
# bestIteration = 134
#
#
# bestTest = 1.839683791
# bestIteration = 194
#
#
# bestTest = 1.873139971
# bestIteration = 115
#
#
# bestTest = 1.610020994
# bestIteration = 133
#
#
# bestTest = 1.748799514
# bestIteration = 183
#
#
# bestTest = 1.686190364
# bestIteration = 81
#
#
# bestTest = 1.761598561
# bestIteration = 39
#
#
# bestTest = 1.642262005
# bestIteration = 160
#
#
# bestTest = 1.617990328
# bestIteration = 113
#
#
# bestTest = 1.644906696
# bestIteration = 125
#
#
# bestTest = 1.779820405
# bestIteration = 35
#
#
# bestTest = 1.639894767
# bestIteration = 196
#
#
# bestTest = 1.622117783
# bestIteration = 98
#
#
# bestTest = 1.712076474
# bestIteration = 108
#
#
# bestTest = 1.808513291
# bestIteration = 69
#
#
# bestTest = 1.618067994
# bestIteration = 199
#
#
# bestTest = 1.563471208
# bestIteration = 133
#
#
# bestTest = 1.693981791
# bestIteration = 128
#
#
# bestTest = 1.82581189
# bestIteration = 81
#
#
# bestTest = 1.654399412
# bestIteration = 196
#
#
# bestTest = 1.691596273
# bestIteration = 106
#
#
# bestTest = 1.70488857
# bestIteration = 127
#
#
# bestTest = 1.834513038
# bestIteration = 69
#
#
# bestTest = 1.663890851
# bestIteration = 199
#
#
# bestTest = 1.672542561
# bestIteration = 199
#
#
# bestTest = 1.705451541
# bestIteration = 120
#
#
# bestTest = 1.730976624
# bestIteration = 130
#
#
# bestTest = 1.704543662
# bestIteration = 197
#
#
# bestTest = 1.746817441
# bestIteration = 88
#
#
# bestTest = 1.83850511
# bestIteration = 132
#
#
# bestTest = 1.985505662
# bestIteration = 13
#
#
# bestTest = 1.712702903
# bestIteration = 196
#
#
# bestTest = 1.699843423
# bestIteration = 180
#
#
# bestTest = 1.898279107
# bestIteration = 75
#
#
# bestTest = 1.914382277
# bestIteration = 32
#
#
# bestTest = 1.689049021
# bestIteration = 197
#
#
# bestTest = 1.685434539
# bestIteration = 184
#
#
# bestTest = 1.77241401
# bestIteration = 126
#
#
# bestTest = 1.877967193
# bestIteration = 30
#
#
# bestTest = 1.709042985
# bestIteration = 187
#
#
# bestTest = 1.805620331
# bestIteration = 198
#
#
# bestTest = 1.803001278
# bestIteration = 146
#
#
# bestTest = 1.850003828
# bestIteration = 66
#
#
# bestTest = 1.733193907
# bestIteration = 199
#
#
# bestTest = 1.838095447
# bestIteration = 184
#
#
# bestTest = 1.840512826
# bestIteration = 199
#
#
# bestTest = 1.93276735
# bestIteration = 112
#
#
# bestTest = 1.789069968
# bestIteration = 194
#
#
# bestTest = 1.748230218
# bestIteration = 199
#
#
# bestTest = 1.858126032
# bestIteration = 199
#
#
# bestTest = 1.898357124
# bestIteration = 183
#
# 0:	learn: 1.9084217	total: 31.6ms	remaining: 6.29s
# 199:	learn: 0.3276044	total: 835ms	remaining: 0us
# Root Mean Squared Error: 1.371407
# Max Error: 5.060117
# Median Abs Error: 0.606341

# %%
df_OS2
# Out:
#   target offset      RMSE       MAE  MaxError  iter  day  month  year  \
# 0   poro    OS2  1.315132  0.636664  4.225198   200   11      1  2022
# 1   poro    OS2  1.371407  0.606341  5.060117   200   11      1  2022
#
#       model version
# 0  catboost  0.26.1
# 1  catboost  0.26.1

# %% [markdown]
# # Combined Results

# %%
frames = [df_OS0, df_OS1, df_OS2]
results = pd.concat(frames)
results
# Out:
#   target offset      RMSE       MAE  MaxError  iter  day  month  year  \
# 0   poro    OS0  1.329398  0.660926  4.725568   200   11      1  2022
# 1   poro    OS0  1.322302  0.689935  4.512723   200   11      1  2022
# 0   poro    OS1  1.636284  0.620747  6.780422   200   11      1  2022
# 1   poro    OS1  1.685559  0.741365  7.131229   200   11      1  2022
# 0   poro    OS2  1.315132  0.636664  4.225198   200   11      1  2022
# 1   poro    OS2  1.371407  0.606341  5.060117   200   11      1  2022
#
#       model version
# 0  catboost  0.26.1
# 1  catboost  0.26.1
# 0  catboost  0.26.1
# 1  catboost  0.26.1
# 0  catboost  0.26.1
# 1  catboost  0.26.1

# %%
results.to_csv('poro_catbost_1_11_v7.csv')
